# %%
# !pip install pubchempy --quiet

# %%
import pandas as pd
import pubchempy as pcp

# %%
def add_smiles_codes(df, column_name='DRUG_NAME'):
    # Check if the specified column name exists in the DataFrame
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in DataFrame.")

    # Function to get SMILES code using pubchempy
    def get_smiles(drug_name):
        try:
            compounds = pcp.get_compounds(drug_name, 'name')
            return compounds[0].isomeric_smiles if compounds else None
        except:
            return None

    # Apply the get_smiles function to each drug name in the specified column
    df['SMILES'] = df[column_name].apply(get_smiles)

    return df

# %%
data = (pd.read_excel(
    'https://cog.sanger.ac.uk/cancerrxgene/GDSC_release8.5/GDSC2_fitted_dose_response_27Oct23.xlsx',
    usecols = ['DRUG_NAME'])
data.sample(5)
# Out:
#                 DRUG_NAME
# 159342             667880
# 160776  L-Oxonoreleagnine
# 140335            LMB_AB2
# 71995      Piperlongumine
# 67619          GSK269962A

# %%
data2 = data[['DRUG_NAME']].drop_duplicates()
data2 = add_smiles_codes(data2)
data2.sample(15)
# Out:
#            DRUG_NAME                                             SMILES
# 3212       Docetaxel  CC1=C2[C@H](C(=O)[C@@]3([C@H](C[C@@H]4[C@]([C@...
# 105808       OSI-027  COC1=CC=CC2=C1NC(=C2)C3=C4C(=NC=NN4C(=N3)C5CCC...
# 55178    Oxaliplatin  C1CC[C@H]([C@@H](C1)[NH-])[NH-].C(=O)(C(=O)O)O...
# 229235       CPI-637  C[C@@H]1CC(=O)NC2=CC=CC(=C2N1)C3=CC4=C(C=C3)N(...
# 139618       LMB_AB1                                               None
# 131018     TAF1_5496                                               None
# 66662     Bortezomib  B([C@H](CC(C)C)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)...
# 148637  Dactinomycin  C[C@@H]1[C@@H](C(=O)N[C@@H](C(=O)N2CCC[C@H]2C(...
# 13858   Lenalidomide              C1CC(=O)NC(=O)C1N2CC3=C(C2=O)C=CC=C3N
# 222367         VE821  CS(=O)(=O)C1=CC=C(C=C1)C2=CN=C(C(=N2)C(=O)NC3=...
# 35486        RO-3306  C1=CC2=C(C=CC(=C2)/C=C\3/C(=O)NC(=NCC4=CC=CS4)...
# 104910    Entinostat  C1=CC=C(C(=C1)N)NC(=O)C2=CC=C(C=C2)CNC(=O)OCC3...
# 91427         LCL161  C[C@@H](C(=O)N[C@@H](C1CCCCC1)C(=O)N2CCC[C@H]2...
# 96181        EPZ5676  CC(C)N(C[C@@H]1[C@H]([C@H]([C@@H](O1)N2C=NC3=C...
# 60822      Erlotinib  COCCOC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC=CC(=C3)C#C...
